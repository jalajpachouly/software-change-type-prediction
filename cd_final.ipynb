# %% [markdown]
# <a href="https://colab.research.google.com/github/jalajpachouly/software-change-type-prediction/blob/main/cd_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""cd_final_with_cross_validation_corrected.py

This script performs multiclass text classification on software defect reports.
It uses SMOTE to balance the dataset and compares the performance of various
machine learning models on both balanced and unbalanced data, using k=10 cross-fold validation.

It generates the following plots:
1. Original Class Distribution
2. Training Data Before SMOTE (Unbalanced)
3. Training Data After SMOTE (Balanced)
4. BERT Training Data Before Oversampling (Unbalanced)
5. BERT Training Data After Oversampling (Balanced)
6. Evaluation of Metrics with all models, box plot - Balanced
7. Evaluation of Metrics with all models, box plot - Unbalanced
8. Evaluation of Metrics with all models, bar plot - Balanced
9. Evaluation of Metrics with all models, bar plot - Unbalanced
10. Word Clouds for each class
"""

# Install necessary libraries
# !pip install transformers -q
# !pip install datasets -q
# !pip install wordcloud -q
# !pip install imbalanced-learn -q  # For SMOTE

# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import nltk
import torch


# NLTK downloads
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab') # Download the punkt_tab resource

# Transformers and tokenizers
from transformers import BertTokenizer, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup

# Data handling
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import LabelEncoder

# Evaluation metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support

# Machine Learning models
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier

# Handling class imbalance
from imblearn.over_sampling import SMOTE

# Handle warnings
import warnings
warnings.filterwarnings('ignore')

# NLTK downloads
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# For progress bar
from tqdm.notebook import tqdm

# Load the dataset
data = pd.read_csv('dataset.csv')

# Display first few rows
print("First few rows of the dataset:")
print(data.head())

# Check for missing values
print("\nMissing values in each column:")
print(data.isnull().sum())

# Distribution of labels
print("\nClass distribution:")
print(data['target'].value_counts())

# Plot label distribution
plt.figure(figsize=(10,6))
sns.countplot(x='target', data=data, order=data['target'].value_counts().index)
plt.xticks(rotation=45)
plt.title('Original Class Distribution')
plt.tight_layout()
plt.savefig('original_class_distribution.png')
plt.show()

import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Initialize lemmatizer and stopwords
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    # Lowercase
    text = text.lower()
    # Remove punctuation and numbers
    text = re.sub(r'[^a-z\s]', '', text)
    # Tokenize
    words = nltk.word_tokenize(text)
    # Remove stopwords and lemmatize
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    # Join back into text
    return ' '.join(words)

# Apply preprocessing
tqdm.pandas()
data['cleaned_text'] = data['report'].progress_apply(preprocess_text)

# Display cleaned text
print("\nSample of original and cleaned text:")
print(data[['report', 'cleaned_text']].head())

# Encode labels
label_encoder = LabelEncoder()
data['label_encoded'] = label_encoder.fit_transform(data['target'])

# Generate word clouds for each class
def generate_wordclouds(data):
    classes = data['target'].unique()
    for cls in classes:
        text = ' '.join(data[data['target'] == cls]['cleaned_text'])
        wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.title(f'Word Cloud for {cls}')
        plt.tight_layout()
        plt.savefig(f'wordcloud_{cls}.png')
        plt.close()

generate_wordclouds(data)

# Initialize models
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000, random_state=42),
    'Linear SVM': LinearSVC(random_state=42),
    'Multinomial NB': MultinomialNB(),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42)
}

# Function to perform cross-validation and collect metrics
from sklearn.model_selection import StratifiedKFold
from sklearn.base import clone

def perform_cv_metrics(models, X, y, data_desc, balance=False):
    # Initialize metrics dictionary
    metrics_dict = {'Model': list(models.keys()), 'Accuracy': [], 'Precision': [], 'Recall': [], 'F1-Score': []}
    # For storing metrics per model across folds
    per_model_metrics = {model_name: {'Accuracy': [], 'Precision': [], 'Recall': [], 'F1-Score': []} for model_name in models.keys()}

    # Initialize StratifiedKFold
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

    fold = 1
    last_y_train = None  # To store y_train from the last fold
    for train_index, test_index in kf.split(X, y):
        print(f"\nFold {fold} for {data_desc} data")
        X_train, X_val = X.iloc[train_index], X.iloc[test_index]
        y_train, y_val = y.iloc[train_index], y.iloc[test_index]

        # Vectorize text using TF-IDF
        tfidf_vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1,2))

        X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
        X_val_tfidf = tfidf_vectorizer.transform(X_val)

        if balance:
            # Apply SMOTE to balance the training data
            smote = SMOTE(random_state=42)
            X_train_tfidf, y_train_smote = smote.fit_resample(X_train_tfidf, y_train)
        else:
            y_train_smote = y_train  # Keep original labels if not balancing

        # Store y_train from the last fold for balancing verification
        if fold == 10 and balance:
            last_y_train = y_train_smote.copy()

        # Train and evaluate models
        for model_name, model in models.items():
            # Clone the model to avoid reusing the same model across folds
            model_clone = clone(model)
            model_clone.fit(X_train_tfidf, y_train_smote)
            y_pred = model_clone.predict(X_val_tfidf)
            accuracy = accuracy_score(y_val, y_pred)
            precision, recall, f1_score, _ = precision_recall_fscore_support(y_val, y_pred, average='weighted', zero_division=0)

            per_model_metrics[model_name]['Accuracy'].append(accuracy)
            per_model_metrics[model_name]['Precision'].append(precision)
            per_model_metrics[model_name]['Recall'].append(recall)
            per_model_metrics[model_name]['F1-Score'].append(f1_score)

            print(f"{model_name} - Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1_score:.2f}")

        fold += 1

    # Calculate average metrics for each model
    for model_name in models.keys():
        metrics_dict['Accuracy'].append(np.mean(per_model_metrics[model_name]['Accuracy']))
        metrics_dict['Precision'].append(np.mean(per_model_metrics[model_name]['Precision']))
        metrics_dict['Recall'].append(np.mean(per_model_metrics[model_name]['Recall']))
        metrics_dict['F1-Score'].append(np.mean(per_model_metrics[model_name]['F1-Score']))

    if balance and last_y_train is not None:
        # Verify the balancing for the last fold
        print("\nAfter SMOTE in the last fold, label distribution:")
        unique, counts = np.unique(last_y_train, return_counts=True)
        print(dict(zip(label_encoder.inverse_transform(unique), counts)))

        # Plot training label distribution after SMOTE (Balanced) for the last fold
        plt.figure(figsize=(12, 5))
        sns.countplot(x=last_y_train, palette='viridis')
        plt.title('Training Data After SMOTE (Balanced) - Last Fold')
        plt.xlabel('Classes')
        plt.ylabel('Count')
        plt.xticks(ticks=range(len(label_encoder.classes_)), labels=label_encoder.classes_, rotation=45)
        plt.tight_layout()
        plt.savefig('training_data_after_smote_last_fold.png')
        plt.show()

    return pd.DataFrame(metrics_dict)

# Prepare data
X = data['cleaned_text']
y = data['label_encoded']

# Collect metrics for unbalanced data using cross-validation
metrics_unbalanced = perform_cv_metrics(models, X, y, data_desc='unbalanced', balance=False)

# Collect metrics for balanced data using cross-validation
metrics_balanced = perform_cv_metrics(models, X, y, data_desc='balanced', balance=True)

# Visualization of Evaluation Metrics

def plot_metrics_box(metrics_df, title):
    plt.figure(figsize=(10,6))
    metrics_melted = metrics_df.melt(id_vars='Model', var_name='Metric', value_name='Score')
    sns.boxplot(x='Metric', y='Score', data=metrics_melted, palette='Set3')
    plt.title(f'Evaluation Metrics - {title} Data', fontsize=14)
    plt.ylabel('Score', fontsize=12)
    plt.xlabel('Metrics', fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    plt.tight_layout()
    plt.show()

def plot_metrics_bar(metrics_df, title):
    metrics_melted = metrics_df.melt(id_vars='Model', var_name='Metric', value_name='Score')
    plt.figure(figsize=(10,6))
    sns.barplot(x='Metric', y='Score', hue='Model', data=metrics_melted, palette='Set2')
    plt.title(f'Evaluation Metrics - {title} Data', fontsize=14)
    plt.ylabel('Score', fontsize=12)
    plt.xlabel('Metrics', fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    plt.legend(title='Model', fontsize=10)
    plt.tight_layout()
    plt.show()

# Generate plots for unbalanced data
plot_metrics_box(metrics_unbalanced, 'Unbalanced')
plot_metrics_bar(metrics_unbalanced, 'Unbalanced')

# Generate plots for balanced data
plot_metrics_box(metrics_balanced, 'Balanced')
plot_metrics_bar(metrics_balanced, 'Balanced')

# ------- BERT Section -------

# For BERT, we will use the original train/test split

# Split data for BERT models (keeping train/test split)
X_train_ml_unbalanced, X_test_ml, y_train_ml_unbalanced, y_test_ml = train_test_split(
    data['cleaned_text'], data['label_encoded'], test_size=0.2, random_state=42, stratify=data['label_encoded'])

# Plot training label distribution before SMOTE (Unbalanced)
plt.figure(figsize=(12, 5))

sns.countplot(x=y_train_ml_unbalanced, palette='viridis')
plt.title('Training Data Before SMOTE (Unbalanced)')
plt.xlabel('Classes')
plt.ylabel('Count')
plt.xticks(ticks=range(len(label_encoder.classes_)), labels=label_encoder.classes_, rotation=45)
plt.tight_layout()
plt.savefig('training_data_before_smote.png')
plt.show()

# Combine training data for BERT
train_data_bert = pd.DataFrame({
    'cleaned_text': X_train_ml_unbalanced,
    'label': y_train_ml_unbalanced
})

# Plot BERT training label distribution before oversampling
plt.figure(figsize=(12, 5))
sns.countplot(x='label', data=train_data_bert, palette='magma')
plt.title('BERT Training Data Before Oversampling (Unbalanced)')
plt.xlabel('Classes')
plt.ylabel('Count')
plt.xticks(ticks=range(len(label_encoder.classes_)), labels=label_encoder.classes_, rotation=45)
plt.tight_layout()
plt.savefig('bert_training_data_before_oversampling.png')
plt.show()

# Oversample the minority classes
from sklearn.utils import resample

train_data_list = [train_data_bert[train_data_bert['label'] == i] for i in range(len(label_encoder.classes_))]
max_size = max(len(d) for d in train_data_list)

train_data_balanced = pd.concat([
    resample(d, replace=True, n_samples=max_size, random_state=42) if len(d) < max_size else d
    for d in train_data_list
])

# Shuffle the balanced training data
train_data_balanced = train_data_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

# Plot BERT training label distribution after oversampling (Balanced)
plt.figure(figsize=(12, 5))
sns.countplot(x='label', data=train_data_balanced, palette='magma')
plt.title('BERT Training Data After Oversampling (Balanced)')
plt.xlabel('Classes')
plt.ylabel('Count')
plt.xticks(ticks=range(len(label_encoder.classes_)), labels=label_encoder.classes_, rotation=45)
plt.tight_layout()
plt.savefig('bert_training_data_after_oversampling.png')
plt.show()

# Tokenize data
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

def tokenize_function(texts):
    return tokenizer(
        texts, add_special_tokens=True, max_length=128, padding='max_length',
        truncation=True, return_attention_mask=True, return_tensors='pt')

# Original unbalanced data
X_train_unbalanced = X_train_ml_unbalanced
y_train_unbalanced = y_train_ml_unbalanced

# Balanced data for BERT
X_train_balanced = train_data_balanced['cleaned_text']
y_train_balanced = train_data_balanced['label']

# Tokenize data for BERT
print("\nTokenizing data for BERT...")

# Unbalanced data
train_encodings_unbalanced = tokenize_function(X_train_unbalanced.tolist())
# Balanced data
train_encodings_balanced = tokenize_function(X_train_balanced.tolist())

test_encodings = tokenize_function(X_test_ml.tolist())

# Convert labels to tensors
train_labels_unbalanced = torch.tensor(y_train_unbalanced.tolist())
train_labels_balanced = torch.tensor(y_train_balanced.tolist())
test_labels = torch.tensor(y_test_ml.tolist())

from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

# Function to create data loaders
def create_data_loader(encodings, labels, batch_size=16):
    dataset = TensorDataset(
        encodings['input_ids'], encodings['attention_mask'], labels)
    data_loader = DataLoader(dataset, sampler=RandomSampler(dataset), batch_size=batch_size)
    return data_loader

# Create data loaders
train_dataloader_unbalanced = create_data_loader(train_encodings_unbalanced, train_labels_unbalanced)
train_dataloader_balanced = create_data_loader(train_encodings_balanced, train_labels_balanced)
test_dataset = TensorDataset(
    test_encodings['input_ids'], test_encodings['attention_mask'], test_labels)
test_dataloader = DataLoader(test_dataset, sampler=SequentialSampler(test_dataset), batch_size=16)

# Function to train and evaluate BERT model
def train_evaluate_bert(train_dataloader, data_desc):
    # Check if GPU is available
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    print(f"\nUsing device: {device} for {data_desc} data")

    # Load pre-trained BERT model
    model = BertForSequenceClassification.from_pretrained(
        'bert-base-uncased', num_labels=len(label_encoder.classes_))
    model.to(device)

    # Optimizer and Scheduler
    optimizer = AdamW(model.parameters(), lr=2e-5, eps=1e-8)
    epochs = 4
    total_steps = len(train_dataloader) * epochs
    scheduler = get_linear_schedule_with_warmup(
        optimizer, num_warmup_steps=0, num_training_steps=total_steps)

    # Training function
    def train():
        model.train()
        total_loss = 0
        progress_bar = tqdm(train_dataloader, desc="Training")
        for batch in progress_bar:
            optimizer.zero_grad()
            input_ids = batch[0].to(device)
            attention_mask = batch[1].to(device)
            labels = batch[2].to(device)
            outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
            loss = outputs.loss
            total_loss += loss.item()
            loss.backward()
            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            scheduler.step()
        avg_loss = total_loss / len(train_dataloader)
        print(f"\nAverage Training Loss: {avg_loss:.4f}")

    # Evaluation function
    def evaluate():
        model.eval()
        predictions, true_labels = [], []
        progress_bar = tqdm(test_dataloader, desc="Evaluating")
        with torch.no_grad():
            for batch in progress_bar:
                input_ids = batch[0].to(device)
                attention_mask = batch[1].to(device)
                labels = batch[2].to('cpu').numpy()
                outputs = model(input_ids, attention_mask=attention_mask)
                logits = outputs.logits
                preds = torch.argmax(logits, axis=1).detach().cpu().numpy()
                predictions.extend(preds)
                true_labels.extend(labels)
        accuracy = accuracy_score(true_labels, predictions)
        report = classification_report(true_labels, predictions, target_names=label_encoder.classes_, output_dict=True)
        print(f"Accuracy on {data_desc} data: {accuracy:.2f}")
        print("Classification Report:")
        print(classification_report(true_labels, predictions, target_names=label_encoder.classes_))
        return accuracy, report

    # Lists to store metrics
    accuracies = []
    reports = []

    # Training loop
    for epoch in range(epochs):
        print(f"\nEpoch {epoch+1}/{epochs} for {data_desc} data")
        train()
        acc, report = evaluate()
        accuracies.append(acc)
        reports.append(report)

    return accuracies, reports

# Train and evaluate BERT on unbalanced data
bert_unbalanced_accuracies, bert_unbalanced_reports = train_evaluate_bert(train_dataloader_unbalanced, "unbalanced")

# Train and evaluate BERT on balanced data
bert_balanced_accuracies, bert_balanced_reports = train_evaluate_bert(train_dataloader_balanced, "balanced")

def add_bert_metrics(metrics_df, bert_reports, bert_accuracies, data_desc):
    # Take the last epoch's metrics
    bert_report = bert_reports[-1]
    # Create a DataFrame for BERT metrics
    bert_metrics_df = pd.DataFrame([{
        'Model': 'BERT',
        'Accuracy': bert_accuracies[-1],
        'Precision': bert_report['weighted avg']['precision'],
        'Recall': bert_report['weighted avg']['recall'],
        'F1-Score': bert_report['weighted avg']['f1-score']
    }])
    # Concatenate with the existing metrics_df
    metrics_df = pd.concat([metrics_df, bert_metrics_df], ignore_index=True)
    return metrics_df

metrics_unbalanced = add_bert_metrics(metrics_unbalanced, bert_unbalanced_reports, bert_unbalanced_accuracies, "unbalanced")
metrics_balanced = add_bert_metrics(metrics_balanced, bert_balanced_reports, bert_balanced_accuracies, "balanced")

# Update plots with BERT metrics
plot_metrics_box(metrics_unbalanced, 'Unbalanced')
plot_metrics_bar(metrics_unbalanced, 'Unbalanced')

plot_metrics_box(metrics_balanced, 'Balanced')
plot_metrics_bar(metrics_balanced, 'Balanced')

print("\nAll tasks completed successfully.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# First few rows of the dataset:
#                                               report          target
# 0  The issue with the JMS Inbound Endpoints revol...  changetype_jms
# 1  The new JMS Observability integration in Sprin...  changetype_jms
# 2  The discussion revolves around enhancing the `...  changetype_jms
# 3  The JMS InboundGateway currently lacks support...  changetype_jms
# 4  The issue INT-2086 addresses inconsistencies i...  changetype_jms
#
# Missing values in each column:
# report    0
# target    0
# dtype: int64
#
# Class distribution:
# target
# changetype_core       994
# changetype_file       180
# changetype_tcp_udp    154
# changetype_build      144
# changetype_jdbc       122
# changetype_jms        120
# changetype_redis      109
# changetype_ftp         93
# changetype_mail        87
# Name: count, dtype: int64
#   0%|          | 0/2003 [00:00<?, ?it/s]
# Sample of original and cleaned text:
#                                               report  \
# 0  The issue with the JMS Inbound Endpoints revol...
# 1  The new JMS Observability integration in Sprin...
# 2  The discussion revolves around enhancing the `...
# 3  The JMS InboundGateway currently lacks support...
# 4  The issue INT-2086 addresses inconsistencies i...
#
#                                         cleaned_text
# 0  issue jms inbound endpoint revolves around jms...
# 1  new jms observability integration spring boot ...
# 2  discussion revolves around enhancing channelpu...
# 3  jms inboundgateway currently lack support dyna...
# 4  issue int address inconsistency different jms ...
#
# Fold 1 for unbalanced data
# Logistic Regression - Accuracy: 0.69, Precision: 0.72, Recall: 0.69, F1-Score: 0.64
# Linear SVM - Accuracy: 0.77, Precision: 0.78, Recall: 0.77, F1-Score: 0.76
# Multinomial NB - Accuracy: 0.52, Precision: 0.32, Recall: 0.52, F1-Score: 0.37
# Random Forest - Accuracy: 0.78, Precision: 0.79, Recall: 0.78, F1-Score: 0.76
#
# Fold 2 for unbalanced data
# Logistic Regression - Accuracy: 0.62, Precision: 0.67, Recall: 0.62, F1-Score: 0.56
# Linear SVM - Accuracy: 0.76, Precision: 0.76, Recall: 0.76, F1-Score: 0.74
# Multinomial NB - Accuracy: 0.50, Precision: 0.32, Recall: 0.50, F1-Score: 0.34
# Random Forest - Accuracy: 0.67, Precision: 0.67, Recall: 0.67, F1-Score: 0.65
#
# Fold 3 for unbalanced data
# Logistic Regression - Accuracy: 0.66, Precision: 0.69, Recall: 0.66, F1-Score: 0.61
# Linear SVM - Accuracy: 0.77, Precision: 0.79, Recall: 0.77, F1-Score: 0.76
# Multinomial NB - Accuracy: 0.50, Precision: 0.32, Recall: 0.50, F1-Score: 0.34
# Random Forest - Accuracy: 0.73, Precision: 0.76, Recall: 0.73, F1-Score: 0.71
#
# Fold 4 for unbalanced data
# Logistic Regression - Accuracy: 0.68, Precision: 0.74, Recall: 0.68, F1-Score: 0.64
# Linear SVM - Accuracy: 0.74, Precision: 0.76, Recall: 0.74, F1-Score: 0.73
# Multinomial NB - Accuracy: 0.49, Precision: 0.25, Recall: 0.49, F1-Score: 0.33
# Random Forest - Accuracy: 0.76, Precision: 0.76, Recall: 0.76, F1-Score: 0.73
#
# Fold 5 for unbalanced data
# Logistic Regression - Accuracy: 0.71, Precision: 0.76, Recall: 0.71, F1-Score: 0.67
# Linear SVM - Accuracy: 0.81, Precision: 0.82, Recall: 0.81, F1-Score: 0.80
# Multinomial NB - Accuracy: 0.51, Precision: 0.32, Recall: 0.51, F1-Score: 0.36
# Random Forest - Accuracy: 0.76, Precision: 0.78, Recall: 0.76, F1-Score: 0.74
#
# Fold 6 for unbalanced data
# Logistic Regression - Accuracy: 0.66, Precision: 0.69, Recall: 0.66, F1-Score: 0.60
# Linear SVM - Accuracy: 0.81, Precision: 0.81, Recall: 0.81, F1-Score: 0.80
# Multinomial NB - Accuracy: 0.51, Precision: 0.40, Recall: 0.51, F1-Score: 0.36
# Random Forest - Accuracy: 0.74, Precision: 0.75, Recall: 0.74, F1-Score: 0.73
#
# Fold 7 for unbalanced data
# Logistic Regression - Accuracy: 0.66, Precision: 0.66, Recall: 0.66, F1-Score: 0.59
# Linear SVM - Accuracy: 0.80, Precision: 0.80, Recall: 0.80, F1-Score: 0.78
# Multinomial NB - Accuracy: 0.49, Precision: 0.25, Recall: 0.49, F1-Score: 0.33
# Random Forest - Accuracy: 0.77, Precision: 0.77, Recall: 0.77, F1-Score: 0.74
#
# Fold 8 for unbalanced data
# Logistic Regression - Accuracy: 0.66, Precision: 0.76, Recall: 0.66, F1-Score: 0.61
# Linear SVM - Accuracy: 0.79, Precision: 0.81, Recall: 0.79, F1-Score: 0.78
# Multinomial NB - Accuracy: 0.49, Precision: 0.24, Recall: 0.49, F1-Score: 0.33
# Random Forest - Accuracy: 0.75, Precision: 0.76, Recall: 0.75, F1-Score: 0.73
#
# Fold 9 for unbalanced data
# Logistic Regression - Accuracy: 0.69, Precision: 0.77, Recall: 0.69, F1-Score: 0.65
# Linear SVM - Accuracy: 0.82, Precision: 0.83, Recall: 0.82, F1-Score: 0.81
# Multinomial NB - Accuracy: 0.51, Precision: 0.32, Recall: 0.51, F1-Score: 0.35
# Random Forest - Accuracy: 0.80, Precision: 0.83, Recall: 0.80, F1-Score: 0.79
#
# Fold 10 for unbalanced data
# Logistic Regression - Accuracy: 0.67, Precision: 0.73, Recall: 0.67, F1-Score: 0.62
# Linear SVM - Accuracy: 0.75, Precision: 0.76, Recall: 0.75, F1-Score: 0.74
# Multinomial NB - Accuracy: 0.51, Precision: 0.32, Recall: 0.51, F1-Score: 0.34
# Random Forest - Accuracy: 0.75, Precision: 0.76, Recall: 0.75, F1-Score: 0.73
#
# Fold 1 for balanced data
# Logistic Regression - Accuracy: 0.82, Precision: 0.82, Recall: 0.82, F1-Score: 0.81
# Linear SVM - Accuracy: 0.83, Precision: 0.83, Recall: 0.83, F1-Score: 0.82
# Multinomial NB - Accuracy: 0.74, Precision: 0.77, Recall: 0.74, F1-Score: 0.74
# Random Forest - Accuracy: 0.80, Precision: 0.82, Recall: 0.80, F1-Score: 0.79
#
# Fold 2 for balanced data
# Logistic Regression - Accuracy: 0.77, Precision: 0.78, Recall: 0.77, F1-Score: 0.76
# Linear SVM - Accuracy: 0.73, Precision: 0.74, Recall: 0.73, F1-Score: 0.73
# Multinomial NB - Accuracy: 0.66, Precision: 0.72, Recall: 0.66, F1-Score: 0.67
# Random Forest - Accuracy: 0.69, Precision: 0.70, Recall: 0.69, F1-Score: 0.68
#
# Fold 3 for balanced data
# Logistic Regression - Accuracy: 0.82, Precision: 0.84, Recall: 0.82, F1-Score: 0.82
# Linear SVM - Accuracy: 0.81, Precision: 0.81, Recall: 0.81, F1-Score: 0.80
# Multinomial NB - Accuracy: 0.70, Precision: 0.76, Recall: 0.70, F1-Score: 0.71
# Random Forest - Accuracy: 0.80, Precision: 0.82, Recall: 0.80, F1-Score: 0.79
#
# Fold 4 for balanced data
# Logistic Regression - Accuracy: 0.74, Precision: 0.74, Recall: 0.74, F1-Score: 0.74
# Linear SVM - Accuracy: 0.75, Precision: 0.75, Recall: 0.75, F1-Score: 0.74
# Multinomial NB - Accuracy: 0.71, Precision: 0.74, Recall: 0.71, F1-Score: 0.72
# Random Forest - Accuracy: 0.77, Precision: 0.77, Recall: 0.77, F1-Score: 0.75
#
# Fold 5 for balanced data
# Logistic Regression - Accuracy: 0.79, Precision: 0.80, Recall: 0.79, F1-Score: 0.78
# Linear SVM - Accuracy: 0.80, Precision: 0.81, Recall: 0.80, F1-Score: 0.79
# Multinomial NB - Accuracy: 0.72, Precision: 0.78, Recall: 0.72, F1-Score: 0.73
# Random Forest - Accuracy: 0.79, Precision: 0.80, Recall: 0.79, F1-Score: 0.78
#
# Fold 6 for balanced data
# Logistic Regression - Accuracy: 0.81, Precision: 0.81, Recall: 0.81, F1-Score: 0.80
# Linear SVM - Accuracy: 0.81, Precision: 0.82, Recall: 0.81, F1-Score: 0.81
# Multinomial NB - Accuracy: 0.69, Precision: 0.74, Recall: 0.69, F1-Score: 0.69
# Random Forest - Accuracy: 0.76, Precision: 0.77, Recall: 0.76, F1-Score: 0.74
#
# Fold 7 for balanced data
# Logistic Regression - Accuracy: 0.79, Precision: 0.78, Recall: 0.79, F1-Score: 0.78
# Linear SVM - Accuracy: 0.81, Precision: 0.80, Recall: 0.81, F1-Score: 0.80
# Multinomial NB - Accuracy: 0.69, Precision: 0.72, Recall: 0.69, F1-Score: 0.70
# Random Forest - Accuracy: 0.78, Precision: 0.80, Recall: 0.78, F1-Score: 0.76
#
# Fold 8 for balanced data
# Logistic Regression - Accuracy: 0.81, Precision: 0.81, Recall: 0.81, F1-Score: 0.80
# Linear SVM - Accuracy: 0.81, Precision: 0.81, Recall: 0.81, F1-Score: 0.81
# Multinomial NB - Accuracy: 0.72, Precision: 0.77, Recall: 0.72, F1-Score: 0.73
# Random Forest - Accuracy: 0.80, Precision: 0.81, Recall: 0.80, F1-Score: 0.79
#
# Fold 9 for balanced data
# Logistic Regression - Accuracy: 0.82, Precision: 0.83, Recall: 0.82, F1-Score: 0.82
# Linear SVM - Accuracy: 0.84, Precision: 0.85, Recall: 0.84, F1-Score: 0.84
# Multinomial NB - Accuracy: 0.73, Precision: 0.77, Recall: 0.73, F1-Score: 0.73
# Random Forest - Accuracy: 0.79, Precision: 0.81, Recall: 0.79, F1-Score: 0.79
#
# Fold 10 for balanced data
# Logistic Regression - Accuracy: 0.79, Precision: 0.80, Recall: 0.79, F1-Score: 0.78
# Linear SVM - Accuracy: 0.78, Precision: 0.78, Recall: 0.78, F1-Score: 0.77
# Multinomial NB - Accuracy: 0.74, Precision: 0.78, Recall: 0.74, F1-Score: 0.74
# Random Forest - Accuracy: 0.73, Precision: 0.76, Recall: 0.73, F1-Score: 0.72
#
# After SMOTE in the last fold, label distribution:
# {'changetype_build': 894, 'changetype_core': 894, 'changetype_file': 894, 'changetype_ftp': 894, 'changetype_jdbc': 894, 'changetype_jms': 894, 'changetype_mail': 894, 'changetype_redis': 894, 'changetype_tcp_udp': 894}
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Tokenizing data for BERT...
#
# Using device: cuda for unbalanced data
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/4 for unbalanced data
# Training:   0%|          | 0/101 [00:00<?, ?it/s]
# Average Training Loss: 1.5893
# Evaluating:   0%|          | 0/26 [00:00<?, ?it/s]
# Accuracy on unbalanced data: 0.66
# Classification Report:
#                     precision    recall  f1-score   support
#
#   changetype_build       0.00      0.00      0.00        29
#    changetype_core       0.73      0.91      0.81       199
#    changetype_file       0.36      0.97      0.52        36
#     changetype_ftp       0.00      0.00      0.00        19
#    changetype_jdbc       0.00      0.00      0.00        24
#     changetype_jms       0.90      0.79      0.84        24
#    changetype_mail       0.00      0.00      0.00        17
#   changetype_redis       0.00      0.00      0.00        22
# changetype_tcp_udp       0.82      0.90      0.86        31
#
#           accuracy                           0.66       401
#          macro avg       0.31      0.40      0.34       401
#       weighted avg       0.51      0.66      0.57       401
#
#
# Epoch 2/4 for unbalanced data
# Training:   0%|          | 0/101 [00:00<?, ?it/s]
# Average Training Loss: 1.0268
# Evaluating:   0%|          | 0/26 [00:00<?, ?it/s]
# Accuracy on unbalanced data: 0.81
# Classification Report:
#                     precision    recall  f1-score   support
#
#   changetype_build       0.63      0.76      0.69        29
#    changetype_core       0.88      0.83      0.86       199
#    changetype_file       0.65      0.89      0.75        36
#     changetype_ftp       0.69      0.47      0.56        19
#    changetype_jdbc       0.69      0.83      0.75        24
#     changetype_jms       0.92      0.92      0.92        24
#    changetype_mail       0.85      1.00      0.92        17
#   changetype_redis       1.00      0.32      0.48        22
# changetype_tcp_udp       0.81      0.94      0.87        31
#
#           accuracy                           0.81       401
#          macro avg       0.79      0.77      0.76       401
#       weighted avg       0.82      0.81      0.80       401
#
#
# Epoch 3/4 for unbalanced data
# Training:   0%|          | 0/101 [00:00<?, ?it/s]
# Average Training Loss: 0.7134
# Evaluating:   0%|          | 0/26 [00:00<?, ?it/s]
# Accuracy on unbalanced data: 0.83
# Classification Report:
#                     precision    recall  f1-score   support
#
#   changetype_build       0.59      0.76      0.67        29
#    changetype_core       0.89      0.86      0.87       199
#    changetype_file       0.76      0.86      0.81        36
#     changetype_ftp       0.68      0.68      0.68        19
#    changetype_jdbc       0.82      0.75      0.78        24
#     changetype_jms       0.92      0.92      0.92        24
#    changetype_mail       0.89      1.00      0.94        17
#   changetype_redis       0.91      0.45      0.61        22
# changetype_tcp_udp       0.80      0.90      0.85        31
#
#           accuracy                           0.83       401
#          macro avg       0.81      0.80      0.79       401
#       weighted avg       0.84      0.83      0.83       401
#
#
# Epoch 4/4 for unbalanced data
# Training:   0%|          | 0/101 [00:00<?, ?it/s]
# Average Training Loss: 0.5789
# Evaluating:   0%|          | 0/26 [00:00<?, ?it/s]
# Accuracy on unbalanced data: 0.85
# Classification Report:
#                     precision    recall  f1-score   support
#
#   changetype_build       0.67      0.76      0.71        29
#    changetype_core       0.91      0.86      0.89       199
#    changetype_file       0.78      0.86      0.82        36
#     changetype_ftp       0.68      0.68      0.68        19
#    changetype_jdbc       0.83      0.79      0.81        24
#     changetype_jms       0.92      0.92      0.92        24
#    changetype_mail       0.89      1.00      0.94        17
#   changetype_redis       0.85      0.77      0.81        22
# changetype_tcp_udp       0.80      0.90      0.85        31
#
#           accuracy                           0.85       401
#          macro avg       0.81      0.84      0.83       401
#       weighted avg       0.85      0.85      0.85       401
#
#
# Using device: cuda for balanced data
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/4 for balanced data
# Training:   0%|          | 0/448 [00:00<?, ?it/s]
# Average Training Loss: 0.7536
# Evaluating:   0%|          | 0/26 [00:00<?, ?it/s]
# Accuracy on balanced data: 0.86
# Classification Report:
#                     precision    recall  f1-score   support
#
#   changetype_build       0.76      0.86      0.81        29
#    changetype_core       0.96      0.82      0.89       199
#    changetype_file       0.83      0.81      0.82        36
#     changetype_ftp       0.67      0.84      0.74        19
#    changetype_jdbc       0.66      0.96      0.78        24
#     changetype_jms       0.92      0.92      0.92        24
#    changetype_mail       0.89      1.00      0.94        17
#   changetype_redis       0.87      0.91      0.89        22
# changetype_tcp_udp       0.79      1.00      0.89        31
#
#           accuracy                           0.86       401
#          macro avg       0.82      0.90      0.85       401
#       weighted avg       0.88      0.86      0.87       401
#
#
# Epoch 2/4 for balanced data
# Training:   0%|          | 0/448 [00:00<?, ?it/s]
# Average Training Loss: 0.1113
# Evaluating:   0%|          | 0/26 [00:00<?, ?it/s]
# Accuracy on balanced data: 0.86
# Classification Report:
#                     precision    recall  f1-score   support
#
#   changetype_build       0.67      0.83      0.74        29
#    changetype_core       0.96      0.83      0.89       199
#    changetype_file       0.70      0.86      0.78        36
#     changetype_ftp       0.71      0.63      0.67        19
#    changetype_jdbc       0.76      0.92      0.83        24
#     changetype_jms       0.92      0.92      0.92        24
#    changetype_mail       0.89      1.00      0.94        17
#   changetype_redis       0.90      0.86      0.88        22
# changetype_tcp_udp       0.82      1.00      0.90        31
#
#           accuracy                           0.86       401
#          macro avg       0.81      0.87      0.84       401
#       weighted avg       0.87      0.86      0.86       401
#
#
# Epoch 3/4 for balanced data
# Training:   0%|          | 0/448 [00:00<?, ?it/s]
# Average Training Loss: 0.0492
# Evaluating:   0%|          | 0/26 [00:00<?, ?it/s]
# Accuracy on balanced data: 0.87
# Classification Report:
#                     precision    recall  f1-score   support
#
#   changetype_build       0.83      0.86      0.85        29
#    changetype_core       0.97      0.86      0.91       199
#    changetype_file       0.77      0.83      0.80        36
#     changetype_ftp       0.57      0.63      0.60        19
#    changetype_jdbc       0.74      0.96      0.84        24
#     changetype_jms       0.88      0.92      0.90        24
#    changetype_mail       0.89      1.00      0.94        17
#   changetype_redis       0.83      0.86      0.84        22
# changetype_tcp_udp       0.86      1.00      0.93        31
#
#           accuracy                           0.87       401
#          macro avg       0.82      0.88      0.85       401
#       weighted avg       0.88      0.87      0.87       401
#
#
# Epoch 4/4 for balanced data
# Training:   0%|          | 0/448 [00:00<?, ?it/s]
# Average Training Loss: 0.0285
# Evaluating:   0%|          | 0/26 [00:00<?, ?it/s]
# Accuracy on balanced data: 0.89
# Classification Report:
#                     precision    recall  f1-score   support
#
#   changetype_build       0.92      0.79      0.85        29
#    changetype_core       0.93      0.91      0.92       199
#    changetype_file       0.77      0.83      0.80        36
#     changetype_ftp       0.75      0.63      0.69        19
#    changetype_jdbc       0.85      0.92      0.88        24
#     changetype_jms       0.88      0.92      0.90        24
#    changetype_mail       0.88      0.88      0.88        17
#   changetype_redis       0.86      0.86      0.86        22
# changetype_tcp_udp       0.86      1.00      0.93        31
#
#           accuracy                           0.89       401
#          macro avg       0.86      0.86      0.86       401
#       weighted avg       0.89      0.89      0.88       401
# All tasks completed successfully.
